# %% [markdown]
# #### Install Tweepy library
# Option 1:
# * Open Command line
# * Install Twitter library using `conda install -c conda-forge tweepy`
#
# Option 2:
# * Open Anaconda Prompt
# * `conda activate nameOfYourEnvironment`
# * `pip install tweepy` (more info on [documentation](https://pypi.org/project/tweepy/))
#
# #### Install wordcloud library
# Option 1:
# * Open Anaconda Prompt
# * `conda activate nameOfYourEnvironment`
# * `pip install wordcloud` (more info on [documentation](https://pypi.org/project/wordcloud/))

# %%
import tweepy as tw
import os
import pandas as pd
import numpy as np
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image

import matplotlib.pyplot as plt

# set working directory
os.chdir("C:/Users/ulloa-to/git/Advanced_Remote_sensing_HM")

# %% [markdown]
# #### Enter your API Keys and Tokens

# %%
API_KEY = "PY38qcq6iZNBIQ3UWhHFl117U"
API_KEY_SECRET = "vmJOsvXLmfXo30ooZMTmSZvMuHQ7vOJW5muxL7OxCCtB8PD58a"
ACCESS_TOKEN = "427763917-UNkMBJ4Ymy4aQNNoWdNWRCnJdfsDOiZumFMo8hYO"
ACCESS_TOKEN_SECRET = "5gh1NAVqnc1sToLaBkwez7pYAuTKXhSNcyXRpVUMioFU4"

auth = tw.OAuthHandler(API_KEY, API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tw.API(auth)

# %% [raw]
# #for obvious reasons i won't write my keys here, but read them from a seperate python file
# #to do this i created a simple python file containing just the variables
#
# #change to the folder of the config file to import it
# os.chdir("C:/Users/ulloa-to/git/Advanced_Remote_sensing_HM")
#
# import config
#
# #in your case, you can also just write them out if you like
# API_KEY = "XXXXXXXXXXXXXXXXX"
# API_KEY_SECRET = "XXXXXXXXXXXXXXXXX"
# ACCESS_TOKEN = "XXXXXXXXXXXXXXXXX"
# ACCESS_TOKEN_SECRET = "XXXXXXXXXXXXXXXXX"
#
# #if you do write them out, remove the "config." from the variables here
# auth = tw.OAuthHandler(config.API_KEY, config.API_KEY_SECRET)
# auth.set_access_token(config.ACCESS_TOKEN, config.ACCESS_TOKEN_SECRET)
#
# api = tw.API(auth)

# %% [markdown]
# #### Search for specific hashtags

# %%
# define hashtag
search_query = "#remotesensing -filter:retweets -filter:replies"

# %% [markdown]
# Use the `tweepy.api` or [Twitter API wrapper](https://docs.tweepy.org/en/v3.5.0/api.html) to retrieve data from the different parts of a tweet and the Twitter community.

# %%
# make the tweets search
search_results = api.search_tweets(q=search_query, lang="en", count = 100)

# %%
# print your tweet results with username: text

for tweet in search_results:
    print("")
    print(tweet.user.screen_name + ":")
    print(tweet.text)
    print("----")
# Out:
# EmisonTech:
# Interested in #remotesensing? Check out this upcoming (FREE!) virtual event from the Pacific Southwest Region of… https://t.co/A8knXwBVwY
# ----
#
# EmisonTech:
# Interested in #remotesensing? Check out this upcoming (FREE!) virtual event from the Pacific Southwest Region of… https://t.co/wAvXWbl5km
# ----
#
# NASA_DEVELOP:
# Happy Veterans Day! @NASA_DEVELOP is proud to support those who have served, offering opportunities to veterans pur… https://t.co/GUVl3rZmZu
# ----
#
# ESIPfed:
# Sessions are in. Dates are set. And registration is open. See you (virtually) in January!
#  https://t.co/CbOUHD1qGm… https://t.co/DLLJiVK8jy
# ----
#
# earth_fromspace:
# #Sentinel 2 (September 2015). NIR-SWIR1-Red, 52 km wide.
# #Bare #Land in #HodhEchChargui, #Mauritania at 278-310 m e… https://t.co/NA28dkeG3h
# ----
#
# UrbanTEP:
# Congratulations to our @DLR_en colleagues for releasing the new version of the World Settlement Footprint (WSF2019)… https://t.co/2ONZCeqTX7
# ----
#
# SARTRAC1:
# Workshop 4 of #Morethanmaps for A-level geographers is now &lt;4 weeks away, so what can you expect? In “What happened… https://t.co/6PfcHqrQ0f
# ----
#
# SpatialityKe:
# We had to install QGIS to get familiar with the https://t.co/uDmNeyejKB plugin. Here are some of the results that w… https://t.co/czxnKjSpeP
# ----
#
# mugorobin:
# Highlights of @SERVIRGlobal regional organizations making a difference in the use of #RemoteSensing data for societ… https://t.co/7hLeRaxDNC
# ----
#
# swricci:
# This morning at #CERF2021! Looking forward to all of the #RemoteSensing talks in the "Developing new insights from… https://t.co/3bRdQDoNXx
# ----
#
# PhilipsonChris:
# I am excited about this new position advertised @PermianGlobal helping us develop #GIS #RemoteSensing  tools to… https://t.co/uLYf2qM7lo
# ----
#
# con20or:
# Irish #remotesensing or #GIS twitter- know any good examples? Big area, lots of old field boundaries- that type of… https://t.co/XKGVYdRHEe
# ----
#
# pedro_biomass:
# #WhereonSAREarth is this city 🏙️? 🤔🛰️🌎🌍🌏
# A very easy one this week 😉
#
# 🛰️C-band @ESA_EO Sentinel-1 multi-temporal V… https://t.co/Jxr2EFLGSB
# ----
#
# AppTechMon:
# #GAMEON -- definitely worth a little effort to garner some free data --
# #remotesensing #RRM #susatoinability #ESG… https://t.co/A7R9EpUfQ9
# ----
#
# Earthworksjobs:
# Senior Program Officer, Forest Carbon Accounting - Washington, DC, USA - https://t.co/GpQHUGSeb2 #jobs #Forestry… https://t.co/6thVizLeKq
# ----
#
# Geoson_FCT:
# #GISDAY #geospatial #innovation #challenge #remotesensing
# GEOSON FCT GIS DAY CELEBRATION
# Join us virtually on zoom… https://t.co/ixVUKCbQsI
# ----
#
# McKenzie_Int:
# We're delighted to announce our membership of @BARSC_EO a company dedicated to promoting the expertise of British-b… https://t.co/cdjUOjJgLo
# ----
#
# CGAT_UPV:
# Special Issue about #forest #fire behaviour modelling using #remotesensing, where our lab member, Prof. Dr. Luis Án… https://t.co/w8yzq18jf9
# ----
#
# azlinszky:
# #Snow drifts and #wetland vegetation highlight #river palaeomeander #microtopography upstream of frozen #Tisza Lake… https://t.co/Izo5jQZPYl
# ----
#
# temjinem:
# PhD fully funded studentship available on "Applications for High Resolution Spaceborne Thermal Imagery".
# Contact Dr… https://t.co/fxNgcLldTH
# ----
#
# RemoteSens_MDPI:
# An Assessment of the #HydrologicalTrends Using Synergistic Approaches of #RemoteSensing and Model Evaluations over… https://t.co/6wVQL1aWvx
# ----
#
# RemoteSens_MDPI:
# Perspectives on the Structural Health Monitoring of #Bridges by #SyntheticApertureRadar
# by Filippo Biondi, Pia Adda… https://t.co/aFuD0Iixro
# ----
#
# igarss2022:
# The International Geoscience and Remote Sensing Symposium 2022 (IGARSS 2022) will be held on 17-22 July 2022 in a h… https://t.co/8IhoLXbAGh
# ----
#
# RemoteSens_MDPI:
# #RemoteSensing of #Burn Severity Using Coupled #Radiative Transfer Model: A Case Study on Chinese Qinyuan Pine… https://t.co/Z5DDgJqH8w
# ----
#
# RemoteSens_MDPI:
# Monitoring Annual Changes of #Lake #Water Levels and Volumes over 1984–2018 Using #Landsat #Imagery and #ICESat-2 D… https://t.co/LZ7qFvwyxj
# ----
#
# RemoteSens_MDPI:
# #CallforPapers
# Special Issue: #RemoteSensing for #Climate Extremes and #Water Resources
# 👨‍🎓Edit by Dr. Yun Chen, Pr… https://t.co/i6Vs61gyFm
# ----
#
# Zeeshan2378:
# A young research scholar and #GIS / #RemoteSensing expert, who perform assigned tasks in organized way, can be acce… https://t.co/LvBabfWdcL
# ----
#
# Onosz:
# #30DayMapChallenge 2021
# Day 10: Raster 🟥🟩🟦
# #BiałowieżaForest 🇵🇱 🌲🌳on satellite images (rasters) 🛰️ in my favorite… https://t.co/qTk3iAFxO5
# ----
#
# PeerJLife:
# 3 Days to submit to the @PeerJLife Special Issue “Innovative Uses of Remote Sensing in Biodiversity Conservation”.… https://t.co/1PZrNCiaz4
# ----
#
# ImagingOrg:
# Big Things Come in Very Small Packages: A New Way of Looking at the Ocean https://t.co/FKtQVB6oNo #imaging… https://t.co/E3KOsC8ubl
# ----
#
# yourforestpdcst:
# Out with some students from @nait Forest Technology class, @forest_tech doing some UAV stuff.
#
# Zoom in to see the… https://t.co/NDOlUEYPn1
# ----
#
# cocovski:
# Are you doing #urban #remotesensing?
# #JURSE2022 Online Lounge is the right event for you! Come and share your rece… https://t.co/R7tSca64fr
# ----
#
# HySpeedGeo:
# Environmental recovery platform launches at COP @StirUni #remotesensing #livinglaboratory #environmentalrecovery
# https://t.co/S33Yg1lKJT
# ----
#
# DescartesLabs:
# Through our partnership with @Unilever we're progressing toward a more symbiotic relationship with the earth and it… https://t.co/SCnG8DKzkS
# ----
#
# wwfspacescience:
# 2 teams unified and on target! Space+Science is delighted to be now part of @WWF_Deutschland Innovation, Sciences,… https://t.co/1y5hNSY3jk
# ----
#
# insilicoplants:
# Quantification of pasture ground cover and botanical composition for sustainable grazing management
#
# @UTAS_… https://t.co/8F5GZCqGfL
# ----
#
# gregcocks_kiwi:
# Earth's Albedo 1998 - 2017 As Measured From Earthshine
# https://t.co/6345rh8iyu
# #GIS #spatial #mapping… https://t.co/hUGYalqVFX
# ----
#
# Fargreenhills:
# Always pushing the boundaries of Landsat data and extracting new info - @txominhermos, @mikewulder, @Joanne_C_White… https://t.co/j6WfQVG3f1
# ----
#
# BryanRVallejo:
# 🌎#30daysmapchallenge Raster 🛰️
# #Geography is fascinating!
# "Chlorophyll concentration during Cromwell Cold Ocean Cu… https://t.co/71luCNwnqR
# ----
#
# ImagingOrg:
# First Light from Landsat 9 https://t.co/LVUpxbxPT7 #imaging #landsat9 #remotesensing https://t.co/FyYA5iUvBh
# ----
#
# CRSS__SCT:
# The significant gaps in QC's flood preparedness regime were uncovered by extensive flooding that inundated most of… https://t.co/UumUZ2M5UZ
# ----
#
# MethodsEcolEvol:
# 🤖We are still accepting article proposals for a Special Feature on active #RemoteSensing, joint with… https://t.co/15hNZ4tkrx
# ----
#
# thatracheljade:
# Ready to face your #RStats fears? I'm giving an Intro to R for Geographic Research talk Friday 230-330 pm EST as pa… https://t.co/EcuXNsMo7m
# ----
#
# ORozenstein:
# #Congrats Imri for winning a #scholarship from the Haim Molcho Foundation for #agricultural #research in the Negev!… https://t.co/71mBjCfMjo
# ----
#
# geomatlab:
# #RemoteSensing #Oceanography
# Remote Sensing, Vol. 13, Pages 4524: Sea-Level Variability in the Arabian Gulf in Comp… https://t.co/JUbEl9OegF
# ----
#
# stripedarmsox:
# Data matters! Taking steps toward healthy #AfricanGreatLakes with a workshop on #remotesensing for monitoring… https://t.co/jqS3lOafDo
# ----
#
# mda524360:
# PhD fully funded studentship on "Applications for High Resolution Spaceborne Thermal Imagery".
#
# Contact Dr. Raffae… https://t.co/NuNvfQSXPh
# ----
#
# SayantanAg:
# We are delighted to announce our recent paper on estimation of peanut LAI and lateral growth using aerial images.… https://t.co/ZVQUIhrqVW
# ----
#
# Julian_H0ffmann:
# Raster Earth -
# #30DayMapChallenge - Day 10 - Raster
#
# Experimental map made from NASA satellite imagery, rerasteris… https://t.co/u98JjpDU3n
# ----
#
# rblourenco:
# A beautiful piece from @globeandmail on the work that @SotheCamile and @AlemuGonsamo have been working on recent mo… https://t.co/OxGkqpeL5b
# ----
#
# rblourenco:
# If you want to hear more about what @AlemuGonsamo and our group are working with, please register and join us!… https://t.co/G456ozRXS2
# ----
#
# BD_007:
# Raster.
# The above-ground carbon in AlAin city, #UAE using pan-sharpened #Landsat-8 OLI imageries.
#
# #biomass #AGB… https://t.co/2iliujjEqG
# ----
#
# Agronomy_Mdpi:
# 📌#Agronomy Paper Published:
#
# " Spatial Prediction of #Agrochemical Properties on the Scale of a Single Field Using… https://t.co/hNVKdUR2k5
# ----
#
# BARSC_EO:
# Read more (https://t.co/H3NVA7iaPe ) on the cooperation between two @BARSC_EO members as @iceyefi announces #flood… https://t.co/BzjfRTd536
# ----
#
# gotruvay:
# Special Section Guest Editorial: Satellite Hyperspectral Remote Sensing: Algorithms and Applications… https://t.co/vxt3fC1Yhg
# ----
#
# haseebharoon3:
# Check out my Gig on Fiverr: do gis, spatial analysis, remote sensing, gis programming https://t.co/AVusXLkiJy
# #GIS… https://t.co/EudRnJ57kG
# ----
#
# Mide_James:
# PhD fully funded studentship available on "Applications for High Resolution Spaceborne Thermal Imagery".
#
# Contact… https://t.co/uNKkVTk6zv
# ----
#
# igarss2022:
# Tutorial proposals are solicited for the 2022 IEEE International Geoscience and Remote Sensing Symposium, to be hel… https://t.co/DFKLRgQqeK
# ----
#
# RemoteSens_MDPI:
# 📢📢📢#CallforAbstract
# The #deadline for the #abstract of The 4th International #Electronic #Conference on… https://t.co/O4bN7RyhvM
# ----
#
# RemoteSens_MDPI:
# Surface Motion Prediction and Mapping for #Road #Infrastructures Management by PS-#InSAR Measurements and… https://t.co/jt2MMZam8k
# ----
#
# RemoteSens_MDPI:
# Estimation of the Number of Endmembers in #Hyperspectral #Images Using Agglomerative Clustering
# by José Prades, Gon… https://t.co/hO0nQzEM0y
# ----
#
# RemoteSens_MDPI:
# Spatio-Temporal Assessment of Global #Precipitation Products over the Largest #Agriculture Region in Pakistan
# by Za… https://t.co/x9an45AVcW
# ----
#
# SkymetWeather:
# At @skAIgeo, open soured data guidance is available for students and researchers to attain knowledge about varied v… https://t.co/FSFUPqpUBg
# ----
#
# skAIgeo:
# At #skAIgeo, open soured data guidance is available for students and researchers to attain knowledge about varied v… https://t.co/HJJzQXdSI6
# ----
#
# GeoNadirAu:
# Using #sentinel2 data we  pinpoint when #mangrove dieback occurred at this far north Qld beach. Then we use #drones… https://t.co/QML5A0rCOT
# ----
#
# agtuary:
# The interactive map in the Agtuary Rainfall tool. 🌧️
# Have a quick view and change what type of data is visualized o… https://t.co/XlgVv5HRCr
# ----
#
# mcgregorcoxall:
# We're proud to announce our Geospatial Scientist, Dr. Hossein Rizeei, has been named as one of 40 rising stars of r… https://t.co/tOJJxBZNMp
# ----
#
# Vinit__Sehgal:
# Interesting to see @FLASHdrought capture #AtmosphericRiver impacts over Western US (wet conditions over NV, UT, WY,… https://t.co/1y8dVDCeNd
# ----
#
# gregcocks_kiwi:
# Seamount Named For Iconic Scripps Oceanographer Walter Munk
# https://t.co/78ZLCrPwak
# #GIS #spatial #mapping… https://t.co/QuIgau6jHQ
# ----
#
# Earthworksjobs:
# Assistant Professor (tenure track) in 4D digital field and structural geology - Lausanne, Switzerland -… https://t.co/IafcltmyRc
# ----
#
# my_physical:
# So, I printed this thing! @USGSLandsat #Landsat9 #gis #Geography #GeographyTeacher #Cartography #Maps #Map #Mapping… https://t.co/XxKlGLbSkz
# ----
#
# ASCEpublishing:
# New @GeoInstitute GSP (322) - guidance on selecting and deploying a #RemoteSensing monitoring network to assess beh… https://t.co/491VIfNDvY
# ----
#
# NLinnovBRA:
# Nov 26: webinar on benefits of @CopernicusEU program for South America #remotesensing. From land, sea and atmospher… https://t.co/EmsTucz2iv
# ----
#
# jpalatiello:
# #GIS #geospatial #remotesensing #surveying #engineering Register at https://t.co/Sv9NVH8LE2 https://t.co/0efg7sKWAs
# ----
#
# KarlHeinzHasliP:
# Hey Satellite Twitter!
# Can you reliably tell from space whether a ricefield is irrigated by full, permanent floodin… https://t.co/l9YQeNX26P
# ----
#
# sentinel_hub:
# ☝️ Learn more about data availability, #remotesensing &amp; #SentinelHub #API 👉 Watch the recoding of our latest… https://t.co/i1izA6GDu1
# ----
#
# Onosz:
# #30DayMapChallenge 2021
# Day 9: Monochrome
#
# Morąg, PL 🇵🇱 - 14 October 1966
# Keyhole KH-7 Gambit, Mission: 4033
# Decl… https://t.co/Hoq0KnjaSS
# ----
#
# geomatlab:
# #RemoteSensing #Oceanography
# Remote Sensing, Vol. 13, Pages 4501: Analyzing Sea Surface Wind Distribution Character… https://t.co/iLlBBoHHOp
# ----
#
# geomatlab:
# #RemoteSensing #Oceanography
# Remote Sensing, Vol. 13, Pages 4499: Drifting Speed of Lagrangian Fronts and Oil Spill… https://t.co/GqhTUIra1y
# ----
#
# LerouxLouise4:
# ⚠️Our new paper is out ⚠️Benchmarking statistical modelling approaches with multi-source #RemoteSensing  data for m… https://t.co/josO9Xlv27
# ----
#
# IUFRO:
# 📢Call for Papers: Forest Disturbance Monitoring Using Satellite #RemoteSensing, for a Special Issue of Remote Sensi… https://t.co/vO4FjjGd1F
# ----
#
# ait_italiana:
# #EuropenJournalofRemoteSensing #RemoteSensing #TaylorandFrancisGroup #SpecialIssue #AIT
# Planet Care from Space – Ca… https://t.co/t7BtppNJi4
# ----
#
# Brillianto_GI:
# #onlinetraining @UKCEH
# Using #drones to map habitats –on demand
# from £349
# https://t.co/UrgeyO6VrZ
#
# #UAV… https://t.co/04EbKab0q9
# ----
#
# valerio_eointel:
# Beautiful #earth
# High-res aerial oblique imagery at its finest!
#
# Follow @valerio_eointel for more:… https://t.co/96inUZWn4S
# ----
#
# NetworkRosewood:
# 🗓️Participate in the 2nd "Forestry Speed Dating" organised with @efibioregions! We'll showcase some of the innovati… https://t.co/lPEHvtEDdZ
# ----
#
# katka_nedbal:
# 🤝 Welcome on #Twitter
# #RemoteSensing &amp; #Airbone Departement @RS_CzechGlobe ❕ https://t.co/oz8aGADqnB https://t.co/jJI2XFhIqM
# ----
#
# manishpatel9074:
# Since we don't speak the language that crops/trees do, We use #RemoteSensing tools to establish the communication.… https://t.co/2olAWiCeeG
# ----
#
# SharynHickey:
# looking for a #postdoc #ecr #AcademicJobs come work with me on #mangroves #seagrass #macroalgae #habitat #mapping w… https://t.co/Pq9toJojoB
# ----
#
# FinIsrael:
# #SpaceTech may not be what comes to mind when thinking of #Finland, but the country has knowhow and potential relat… https://t.co/RMKToXmAFT
# ----
#
# EO_factory:
# Can drones replace their higher altitude counterparts?
#
# EOfactory’s CEO Abhay Mittal talks about this and more in t… https://t.co/Y4FB8tEu2g
# ----
#
# vitalsignsdata:
# 📢 Join @TomKiptenai, our #RemoteSensing Analyst, and @endenga, our M&amp;E specialist, + other experts for this engagin… https://t.co/lMscAGUOze
# ----
#
# BeijingEvening:
# China's #Mars probe #Tianwen1 completed its 5th braking maneuver on 8th(Beijing time), engineers have calculated a… https://t.co/RSgXtPmzSB
# ----
#
# InformationMDPI:
# #HighCitedPublication
# Views: 13514
# Citations: 110
#
# “A Review on UAV-Based Applications for Precision Agriculture”,… https://t.co/pEPqPaA4dT
# ----
#
# JosephShea:
# Winter semester seats still available for @UNBCGeography #GEOG102: Earth From Above!
#
# #geoscience #remotesensing… https://t.co/xxgX2AL39I
# ----
#
# PeerJLife:
# Final week to submit to the @PeerJLife Special Issue “Innovative Uses of Remote Sensing in Biodiversity Conservatio… https://t.co/OS5PCtRDqX
# ----
#
# Sensors_MDPI:
# Phenotyping of Plant Biomass and Performance Traits Using #RemoteSensing Techniques in Pea (Pisum sativum, L.)… https://t.co/iTO1KxVgPu
# ----
#
# GeoNadirAu:
# Flooded agricultural field #dronemapping in Luxembourg after the 2021 European Flood by @MB_RSShydro via #GeoNadir… https://t.co/h3Xor7kYQS
# ----
#
# patyllanos:
# Lets support @Onosz 🇵🇱 💪🏻
# #GIS #RemoteSensing #EarthObservation👇🏻 https://t.co/g79o22i0So
# ----
#
# IISL_KC:
# 🌠This week the @iisl_space Knowledge Constellation presents the critical and insightful topic of “Remote Sensing La… https://t.co/B7X0Wvpnke
# ----
#
# OPNmagazine:
# OPN Feature: #Laser-scanning instruments that allow #hyperspectral and spatial data to be collected in a single sho… https://t.co/HXBhEsQXkT
# ----

# %% [markdown]
# Dump all the tweets into a Data Frame. This way you can export your data, and process it further.

# %%
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
#pd.set_option('display.max_rows', None)
twdf = pd.DataFrame(data=[[tweet.user.screen_name, tweet.text, tweet.created_at] for tweet in search_results], columns=["UserName","Tweet_Text","Tweet_Date"])
twdf.head()
# Out:
#           UserName  \
# 0       EmisonTech
# 1       EmisonTech
# 2     NASA_DEVELOP
# 3          ESIPfed
# 4  earth_fromspace
#
#                                                                                                                                       Tweet_Text  \
# 0      Interested in #remotesensing? Check out this upcoming (FREE!) virtual event from the Pacific Southwest Region of… https://t.co/A8knXwBVwY
# 1      Interested in #remotesensing? Check out this upcoming (FREE!) virtual event from the Pacific Southwest Region of… https://t.co/wAvXWbl5km
# 2   Happy Veterans Day! @NASA_DEVELOP is proud to support those who have served, offering opportunities to veterans pur… https://t.co/GUVl3rZmZu
# 3   Sessions are in. Dates are set. And registration is open. See you (virtually) in January!\n https://t.co/CbOUHD1qGm… https://t.co/DLLJiVK8jy
# 4  #Sentinel 2 (September 2015). NIR-SWIR1-Red, 52 km wide.\n#Bare #Land in #HodhEchChargui, #Mauritania at 278-310 m e… https://t.co/NA28dkeG3h
#
#                  Tweet_Date
# 0 2021-11-11 18:22:12+00:00
# 1 2021-11-11 18:15:07+00:00
# 2 2021-11-11 16:19:45+00:00
# 3 2021-11-11 16:11:00+00:00
# 4 2021-11-11 16:00:26+00:00

# %% [markdown]
# #### Retrieve information from your home
#
# `API.home_timeline`: Returns the 20 most recent statuses, including retweets, posted by the authenticating user and that user’s friends. This is the equivalent of /timeline/home on the Web.

# %%
# define how many tweets you want to retrieve. Exclude retweets
home_tweets = api.home_timeline(count=100, exclude_replies = True)

# %%
#text file for wordcloud, if you want to filter your tweets. in this case by excluding everything not in english language
home_text_en = ""

for tweet in home_tweets:
    print("")
    print(tweet.user.screen_name + ":")
    if tweet.lang == "en":
        home_text_en += tweet.text+" "
    print(tweet.text)
    print("----")
# Out:
# UNDPClimate:
# #ClimateChange remains one of the most critical issues of our time. Digital solutions can help us reduce its impact… https://t.co/Rv5PcmZwaZ
# ----
#
# Pettorelli:
# RT @adamvaughan_uk: #COP26 officially finishes 6pm Fri. Former UN climate chief @CFigueres tells me: "From the maturity of the [draft] text…
# ----
#
# PIK_Climate:
# RT @Forum4theFuture: As conversations gather pace at COP26, @jrockstrom, Director of the @PIK_Climate, reframes the question we all need to…
# ----
#
# IPBES:
# RT @JanBebbington: An important engagement opportunity @BathCBOS @UoBResponsible @sthlmresilience @PentlandCentre @ERGO_RG @cisl_cambridge…
# ----
#
# NatGeo:
# Happy #NativeAmericanHeritageMonth! We're doing a Q&amp;A with @insidenatgeo Explorer &amp; Poet Rena Priest (@RenaPriest).… https://t.co/JKbdlmPTEH
# ----
#
# adriana_humanes:
# RT @aveb_ve: La Tagura de Darwin. Ronda 1x8: Historias que Inspiran Vol 2: Una Microbióloga Pariaguanera🧫.
#
# No olvides darle Like y comenta…
# ----
#
# IPBES:
# RT @RamsarConv: Rewetting #peatlands is essential for climate but also for adaptation and combatting land degradation.
#
# Peatlands protect a…
# ----
#
# adriana_humanes:
# RT @RubbyCobain: Deberíamos hacer un hilo donde todos aportemos psicólogos para quienes lo necesiten👇🏻
#
# Si quieres compartirlo puedes respo…
# ----
#
# adriana_humanes:
# RT @morontafelix: El virus de la viruela se ha extinguido*. El virus de la polio, de la rubeola y del sarampión podrían tener el mismo dest…
# ----
#
# AlelimonHA:
# Estamos listos! 10min para comenzar con nuestra segunda jornada de #CoralLive2021 con @encounteredu aquí:… https://t.co/OuLNUgfXox
# ----
#
# UNDPClimate:
# RT @CIP_climate: Our recent call for proposal is helping advance #energyaccess, and #climateaction in communities,  cities, and regions in…
# ----
#
# IPBES:
# RT @IUCN: Marine heatwaves make extreme weather more likely, and negatively affect livelihoods.
#
# In the last 10 years, they’ve become 50% m…
# ----
#
# IPBES:
# RT @guardianeco: ‘Natural Health Service’: Derby approves UK’s largest urban rewilding project https://t.co/K6avX4JiPt
# ----
#
# ReneeGoust:
# RT @Reactor105: Esta mañana tendremos mucha música y sorpresas en #CuandoElFuturoNosAlcance. Escuchen a @zaipadron y @radiorlando con la se…
# ----
#
# PIK_Klima:
# RT @MCC_Berlin: Der Stifterverband für die Deutsche Wissenschaft @stifterverband ehrt Ottmar #Edenhofer: Der Direktor von @MCC_Berlin und @…
# ----
#
# Pettorelli:
# RT @LBurnelius: 'If the world behaved like the EU - an awful lot of wood would be burned'
# A @washingtonpost investigation show a significa…
# ----
#
# CIFOR:
# #COP26 deforestation pledges a big win, but only if they are upheld: Key is to ensure promises are met, says CIFOR-… https://t.co/0q9XFSwb9F
# ----
#
# PIK_Klima:
# Wer es gestern verpasst hat: PIK's @BjoernSoergel sprach mit Harald #Lesch &amp; @JasminaDaria bei #TerraX Lesch &amp; Co i… https://t.co/cX4YhI1dOZ
# ----
#
# IPBES:
# RT @WRIClimate: To make faster progress on the #SDGs, our planet needs thriving, low-carbon cities. 7 transformations can tackle inequality…
# ----
#
# BMZ_Bund:
# RT @DIE_GDI: 📢
#
# The BMZ African-German Leadership Academy is now inviting applications for the 2022 participants. 🌍
#
# Watch this video to le…
# ----
#
# PIK_Climate:
# Ottmar #Edenhofer, PIK Director &amp; Climate Economist, receives the Arthur Burckhardt Prize 2021 from @stifterverband… https://t.co/j458Og9n0P
# ----
#
# NatGeo:
# Originally in remembrance of the end of World War I—on the 11th month, the 11th day, and the 11th hour in 1918—toda… https://t.co/RaazaNnGZ0
# ----
#
# IPBES:
# RT @WBG_Climate: Find out how Africa’s megacity, Kinshasa, is putting #ClimateAction, urban management, and resilient infrastructure at the…
# ----
#
# IPBES:
# RT @FAOstatistics: 🔥🔥🔥 off the presses ‼️
#
# Out TODAY, our 🆕edition of the @FAO Food Outlook: Biannual Report on Global Food Markets
#
# Downlo…
# ----
#
# PIK_Klima:
# RT @LinusMattauch: Große Ehre einmal einmal
#   mit @berndulrich von  @DIEZEIT
#  für die @Junge_Akademie diskutieren zu dürfen! @TUBerlin @PI…
# ----
#
# sthlmresilience:
# RT @RominaXMartin: "Who are experts to adapt to climate change?" Just enjoyed the latest @Rethink_Earth podcast episode https://t.co/PJ9em9…
# ----
#
# IPBES:
# RT @UNBiodiversity: A dataviz created by @IPCC_CH author @ed_hawkins shows how global temperatures have risen by 1°C.
#
# We must act urgently…
# ----
#
# PIK_Klima:
# Ottmar #Edenhofer, PIK Direktor &amp; #Klimaökonom,  erhält den Arthur Burckhardt-Preis 2021 von @stifterverband als "h… https://t.co/rKHGTwvCjB
# ----
#
# IPBES:
# "Choose ambition. Choose solidarity. Choose to safeguard our future and save humanity."
#
# In a speech to #COP26,… https://t.co/XpxjJCIduv
# ----
#
# AcademicsSay:
# define normal https://t.co/3RrzJjtKI7
# ----
#
# UNDPClimate:
# When it comes to the climate crisis, and expectations from #COP26, what's on young people's minds?
#
# Join our Twitte… https://t.co/6zLF8GImOl
# ----
#
# IPBES:
# RT @wef: 5 critical incentives that could protect nature and the climate https://t.co/42hExAKAKw https://t.co/kVqHZXRm35
# ----
#
# IPBES:
# RT @UNBiodiversity: 🎧 #NowListening: @mremae discusses climate change and #biodiversity loss on @wef's #RadioDavos podcast
#
# The CBD Exec Se…
# ----
#
# sthlmresilience:
# RT @anne_bunge: Is there a way to provide a complex comprehensive sustainability assessment of food products and translate it into easy -un…
# ----
#
# UNDPClimate:
# ATTN: World leaders at #COP26
#
# 70% of people under 18 in G20 countries believe we are in a state of climate emergen… https://t.co/z7fiv55cMY
# ----
#
# NatGeo:
# Hospitals are incorporating new strategies to make medical procedures for infants—especially premature babies—less… https://t.co/iQA8YXULMe
# ----
#
# IPBES:
# RT @EU_GreenFuture: NEW: @UNEP has released an addendum to the #EmissionsGap Report 2021. The update serves as a preliminary assessment of…
# ----
#
# BMZ_Bund:
# 📢 From connection to action! 📢
# Yesterday was the annual meeting of the #ActionNetwork on Forced Displacement –… https://t.co/e3zONisITW
# ----
#
# ESA_CAVES:
# At @GeoparkLanzarot Mirador del Rio #pangaea  https://t.co/kudDHmZlIJ
# ----
#
# ESA_CAVES:
# #pangaea tour of @GeoparkLanzarot - drawing exercise of the Famara series at Mirador del Rio https://t.co/xStXPtb7zn
# ----
#
# ESA_CAVES:
# RT @ESA_Italia: Astronauti Esa e Nasa a Lanzarote per la missione "Pangea" https://t.co/i86K33cMG6 #Pangaea @ESA_CAVES @esa @esa_es
# ----
#
# kearneymw:
# https://t.co/7ct9uXHpOK https://t.co/M3QzkzMOWG
# ----
#
# UNDPClimate:
# ⚡️LIVE FROM #COP26: Join @RockyMtnInst, @UNDP sustainable energy expert Camila Gonzalez and partners now at the… https://t.co/w4w0YUJ4Vk
# ----
#
# Pettorelli:
# RT @JNCC_UK: #WeAreRecruiting a Marine Ornithologist https://t.co/EnkGw8Ald1 to manage the VSAS programme and contribute to other seabird m…
# ----
#
# PHDcomics:
# So that's why it's called an abstract https://t.co/C82rTHTpGE
# ----
#
# Pettorelli:
# RT @JRThompson_UCL: World’s ‘calamitous’ water crisis being ignored in climate talks – WaterAid https://t.co/fIKbbRpnEq
# ----
#
# IPBES:
# RT @UNBiodiversity: 🌎 1000+ youth voices. 118 countries. 🌍
#
# The Global Youth Position Statement on #NatureBasedSolutions is here.
#
# Launched…
# ----
#
# IPBES:
# RT @CapsCoalition: Natural Capital Valuation: An Incentive To Protect Nature?
#
# A new @SPGlobal report finds that "The sustainable use of na…
# ----
#
# kearneymw:
# I am not wearing a Boys II Men shirt, sweat pants, and a neon fanny pack to work in because that would be ridiculous. 😉
# ----
#
# IPBES:
# RT @JohnEScanlon: Biodiversity loss, #climatechange &amp; pandemics are global crises with something in common – they are exacerbated by illici…
# ----
#
# CIFOR:
# #ForestsNews: Craft tenure policies to protect women’s right to gather harvests from trees and engage in land-relat… https://t.co/aIZMvUR1YR
# ----
#
# NatGeo:
# Safe underground from the inhuman chaos of the battlefield above, the men of the First World War left their persona… https://t.co/u1rJRzsw7L
# ----
#
# BMZ_Bund:
# #Stellenausschreibung: Wir suchen Sachbearbeiterinnen/Sachbearbeiter (w/m/d) im gehobenen Dienst für verschiedene A… https://t.co/tRVAvN4tNL
# ----
#
# IPBES:
# The world has come #TogetherForOurPlanet🌿
#
# Biodiversity loss &amp; #ClimateChange are two sides of the same coin. Neith… https://t.co/9XHtPOxGDj
# ----
#
# IPBES:
# RT @ESPartnership: Register now for the ESP Asia online conference this December! Early Bird deadline - 15 November
# 🦢🦜🐦
# You can still submi…
# ----
#
# PIK_Klima:
# ⏰Am Sa., 13.11. um 10 Uhr beginnt der NRW Klimakongress #NRWklimaneutral. PIK-Forscher Christoph #Bertram spricht i… https://t.co/GjFeW2carf
# ----
#
# IPBES:
# RT @CapsCoalition: New Partnership Aims to Remove Barriers to Indigenous Climate Finance:
#
# A new international coalition of organizations &amp;…
# ----
#
# UNDPClimate:
# Greening transportation is vital for cities to achieve net-zero emissions.
#
# It also means Norzilla can avoid well… https://t.co/3DZLSa3ZwG
# ----
#
# IPBES:
# RT @IUCN: IUCN Director General Bruno Oberle to #COP26: Nature-based Solutions are cost-effective ways to address adaptation and mitigation…
# ----
#
# PIK_Climate:
# ⏰Tomorrow, 11/12 1pm UK time: Ridding the streets of #fossil powered cars – that’s one aim of #COP26. What does sci… https://t.co/zPttntEsJn
# ----
#
# PIK_Klima:
# ⏰Tomorrow, 11/12 1pm UK time: Ridding the streets of #fossil powered cars – that’s one aim of #COP26. What does sci… https://t.co/YOMCmj5xhF
# ----
#
# AcademicsSay:
# RT @AcademicsSay: "We're all smart. Distinguish yourself by being kind." - C. Gordon, via @annegalloway
# ----
#
# UFZ_de:
# Nachrichten-Blog zur UN-Klimakonferenz in Glasgow | https://t.co/5DXmt8qTDv https://t.co/fGBDKogz2n
# ----
#
# PradeepUNDP:
# RT @UNDP: Excuses start to sound pretty stupid when the alternative is extinction.
#
# It’s time to choose #ClimateAction instead.
#
# Join us an…
# ----
#
# PradeepUNDP:
# RT @meganrowling: Latest on #COP26 #climate negotiations: there won't be new cover decision texts until tonight/tomorrow AM as push continu…
# ----
#
# PradeepUNDP:
# RT @UNDP_Sweden: With support of the @GlobalFund, @UNDP has extended a lifeline to the health system in #Afghanistan   by paying the salari…
# ----
#
# PradeepUNDP:
# RT @antonioguterres: One day before the end of #COP26, we cannot settle for the lowest common #ClimateAction denominator.
#
# I appeal to all…
# ----
#
# IPBES:
# RT @CrowtherLab: A meta-analysis of the ecological and economic outcomes of mangrove restoration: https://t.co/ASDqRNBY4F #GenerationRestor…
# ----
#
# Luismmontilla:
# RT @d_giovannelli: Tonight 11 Nov at 6 pm Italian time @ArielAnbar will give a talk for the @SocGeol Geobiology seminar serie on "Looking f…
# ----
#
# motoko42:
# RT @moritz_roedle: Wahlverhalten der Nicht-geimpften: CDU, SPD, Grüne deutlich unterdurchschnittlich. FDP und Linke unterdurchschnittlich,…
# ----
#
# motoko42:
# Gute Regelung! Und: 2G als "2 gay", finde ich aber auch super! :-D https://t.co/XfrNcmWZRa
# ----
#
# IPBES:
# RT @CapsCoalition: Study Shows ‘Encouraging’ Results of China’s Bid to Protect Coastal Wetlands:
#
# China lost 50% of its coastal wetlands in…
# ----
#
# CIFOR:
# 🔴 #HappeningNow: CIFOR-@ICRAF at #COP26
#
# 💡 Fair and equitable REDD+ finance and benefit-sharing mechanisms for clim… https://t.co/fpsvIz4PWB
# ----
#
# NatGeo:
# Along with their backpacks and growth spurts, students are bringing lingering trauma to school with them. "It’s not… https://t.co/hSJ7LR91aA
# ----
#
# sthlmresilience:
# We're excited to share this brand new animation based on the SDG "wedding cake", which shows the biosphere as the f… https://t.co/93bH4NbYur
# ----
#
# IPBES:
# Mangroves are critical to addressing #ClimateChange🌳💧🦆
#
# They store over 21 billion tons of CO2 &amp; sequester carbon 4… https://t.co/kIEmpWzJ66
# ----
#
# PradeepUNDP:
# The Climate Crisis is happening NOW. We need action FAST. We need action to be FAIR and not leave the most vulnerab… https://t.co/38eJyxjHUZ
# ----
#
# UNDPClimate:
# Speaking at the #COP26 @UN_Energy event this week, @ASteiner outlined that we are in the midst of an energy revolut… https://t.co/UStmVXQcL2
# ----
#
# PradeepUNDP:
# "Coal is not a fuel source of the future."
#
# - @UNDP Administrator, @ASteiner speaking at #COP26 @UN_Energy event t… https://t.co/6mclqlnAVe
# ----
#
# CIFOR:
# 🌳 Nature-based solutions remain one of the most viable and cost-effective approaches in mitigating the negative eff… https://t.co/IDuzeRb9MQ
# ----
#
# CIFOR:
# RT @lawinowiecki: @ICRAF @CIFOR highlighting farmer-centered #landscape #GenerationRestoration
# https://t.co/mIe71yUh3Z
#
# This #COP26 sessio…
# ----
#
# CIFOR:
# RT @ICRAF: 🔴 Now happening at #COP26 @IFAD Pavilion
#
# 🌳Scaling up community-driven innovations for inclusive climate change adaptation
#
# 📺 Tu…
# ----
#
# UNDPClimate:
# RT @UNDPKAZ: Climate crisis is real and it is happening NOW and we need action FAST.
# Check the message from #Kazakhstan's photographer Osp…
# ----

# %% [markdown]
# Dump all the tweets into a Data Frame. This way you can export your data, and process it further.

# %%
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
#pd.set_option('display.max_rows', None)
homedf = pd.DataFrame(data=[[tweet.user.screen_name, tweet.text] for tweet in home_tweets], columns=["UserName", "Tweet_Text"])
homedf.head()
# Out:
#       UserName  \
# 0  UNDPClimate
# 1   Pettorelli
# 2  PIK_Climate
# 3        IPBES
# 4       NatGeo
#
#                                                                                                                                              Tweet_Text
# 0          #ClimateChange remains one of the most critical issues of our time. Digital solutions can help us reduce its impact… https://t.co/Rv5PcmZwaZ
# 1          RT @adamvaughan_uk: #COP26 officially finishes 6pm Fri. Former UN climate chief @CFigueres tells me: "From the maturity of the [draft] text…
# 2          RT @Forum4theFuture: As conversations gather pace at COP26, @jrockstrom, Director of the @PIK_Climate, reframes the question we all need to…
# 3           RT @JanBebbington: An important engagement opportunity @BathCBOS @UoBResponsible @sthlmresilience @PentlandCentre @ERGO_RG @cisl_cambridge…
# 4  Happy #NativeAmericanHeritageMonth! We're doing a Q&amp;A with @insidenatgeo Explorer &amp; Poet Rena Priest (@RenaPriest).… https://t.co/JKbdlmPTEH

# %% [markdown]
# #### Explore specific users
#
# `api.user_timeline`: Returns the 20 most recent statuses posted from the authenticating user or the user specified. It’s also possible to request another user’s timeline via the id parameter.

# %%
userTweets = api.user_timeline(screen_name="NatGeo", count=100, include_rts = False, exclude_replies=True)

# %%
user_text_all = ""
for tweet in userTweets:
    user_text_all += tweet.text+" "
    print(tweet.text)
# Out:
# Happy #NativeAmericanHeritageMonth! We're doing a Q&amp;A with @insidenatgeo Explorer &amp; Poet Rena Priest (@RenaPriest).… https://t.co/JKbdlmPTEH
# Originally in remembrance of the end of World War I—on the 11th month, the 11th day, and the 11th hour in 1918—toda… https://t.co/RaazaNnGZ0
# Hospitals are incorporating new strategies to make medical procedures for infants—especially premature babies—less… https://t.co/iQA8YXULMe
# Safe underground from the inhuman chaos of the battlefield above, the men of the First World War left their persona… https://t.co/u1rJRzsw7L
# Along with their backpacks and growth spurts, students are bringing lingering trauma to school with them. "It’s not… https://t.co/hSJ7LR91aA
# The tools and fashions of 18th-century wigmaking live on at the living history museum at Colonial Williamsburg, Vir… https://t.co/W0JDimrh4G
# Find holy history and heavenly vintages in the northern reaches of this celebrated French wine-making region https://t.co/WucGyBr276
# More than 200 million years ago, modern frogs’ ancestors lost the teeth in their lower jaws. How did Guenther’s mar… https://t.co/Gs06hg1EhK
# Destined for museum gift shops, these replicas of ancient Greek statues promote the country's heritage—and give sou… https://t.co/zj1jkr1bTt
# Here’s how the holiday evolved from a day of postwar mourning to a celebration of all those who have served in the… https://t.co/lG7OwRtXeW
# Enjoy your daily moment of wonder! #TheWorldAccordingToJeffGoldblum season 2 premieres on #DisneyPlusDay, Nov. 12… https://t.co/yszjyYeBTR
# India has pledged to become carbon-neutral by 2070. In the mean time, solar entrepreneurs aim to end that reliance… https://t.co/gbbhqywQ5T
# How did a bird that’s common in the foothills of the Himalaya and the equatorial forests of Africa come to London? https://t.co/HtD6hgfEaV
# Bulgaria has the highest rate of premature deaths caused by air pollution in the EU—and coal burning is a major con… https://t.co/tx4YrkBGaQ
# What are you streaming? Get one month of @DisneyPlus for $1.99, today through November 14 #DisneyPlusDay… https://t.co/vvQkGw0IPk
# The lush Gaoligong mountains of Yunnan Province offer glimpses of an older Earth teeming with animals and plants https://t.co/8XFEjvF1E2
# For divers who want to go deeper and stay longer than conventional gear allows, this submersible "tent" is a game-c… https://t.co/553ErnTkEU
# These entities thrived for centuries before they disappeared—how many do you know? https://t.co/RAY986iLJW
# Otters, foxes, and other wild animals may seem like they would be cute and cuddly pets, but the reality is far more… https://t.co/rNpGSyDTI1
# Find holy history and heavenly vintages in the northern reaches of this celebrated French wine-making region https://t.co/dMODILNnz9
# This colorful little seahorse is the size of a grain of rice https://t.co/RgArJsaqzH
# The fossil's $7.7-million sale has some experts worried that ancient bones' rising prices will put more scientifica… https://t.co/XBJylwMw4d
# The flooding has disrupted everything—from the economy to health and education. The hardest hit segment of the popu… https://t.co/wqgs7NxVlK
# First Diana Markosian found her father. Then she found her grandfather. Then she found part of herself. https://t.co/jnvRGIscAP
# India has pledged to become carbon-neutral by 2070. In the mean time, solar entrepreneurs aim to end that reliance… https://t.co/7dlDFnldNH
# On the latest episode of #OverheardNatGeo, National Geographic photographer Diana Markosian tells the story of an u… https://t.co/OV2t1qmqTK
# Once a cultural way station for immigrants, this ever-evolving neighborhood offers an authentic taste of Korean cul… https://t.co/lcd5QVhGHP
# "For the Lamalerans, the global pandemic meant a year free from backpackers and outsiders, foreign and Indonesian,… https://t.co/L5k0bbmjZ3
# The demand for painted snails—which have long been sought by collectors—is one reason why Cuba lists all six specie… https://t.co/nSnY7AwMkI
# Did you know salmon use smell to navigate back to their original spawning grounds during their perilous, exhausting… https://t.co/Mj1FzAoAcJ
# The majority of gorilla selfies that researchers found on Instagram violated social distancing rules meant to keep… https://t.co/HI4vnfdHFh
# Bulgaria has the highest rate of premature deaths caused by air pollution in the EU—and coal burning is a major con… https://t.co/tE7yZpcIMw
# On National #STEMDay, learn how sexism has long skewed research—but a new wave of scientists is shifting course https://t.co/yPfsXuyxTI
# This is a living planet, and everything is connected. Discover more of National Geographic on @DisneyPlus, and get… https://t.co/Cxth76lR3t
# The fossil's $7.7-million sale has some experts worried that ancient bones' rising prices will put more scientifica… https://t.co/N8V5WQ5hjv
# #NativeAmericanHeritageMonth Fact: Montezuma Castle, constructed by the Sinagua people around 1150, is one of the b… https://t.co/rneYLrfcuq
# Portraits of high school students Vongayi Marazanye, Naisha Chowdhury, and Amanda Shayna Ahteck, at the Internation… https://t.co/1hyLbSOc6K
# Experts agree that a day off from school can recharge burned-out kids https://t.co/I1EOekI1P5
# Don't miss our @Reddit AMA with archaeologist and journalist @arwilliams1117 TODAY at 11am ET:… https://t.co/hxV166RrGp
# Glasgow—whose Gaelic name, Glaschu, fittingly means “dear green place”—is abuzz with new openings as it hosts Novem… https://t.co/J8tGmkxsXU
# Even if it drives parents crazy, the use of slang has definite cognitive and emotional benefits for children https://t.co/XEFVkB4fj0
# Hector and Achilles might have been the stars of Homer’s epic poem, but their helmets, shields, and weapons are wha… https://t.co/1TEU0gZcRN
# Hornbills are tropical birds named for their unusually large, curved bills, some of which are adorned with a large… https://t.co/s0SOks8wjZ
# After years of bringing his wife bouquets, Abelardo Morell switched to a more enduring gift: photographs with an im… https://t.co/vQaJtTeRZ7
# Altiplano is one of the harshest regions of the Andes Mountains, hostile towards all life—except flamingoes https://t.co/pVNvFRKO6a
# Dog lovers proud of their country's unique breed want to make their lives better—and prevent the spread of rabies https://t.co/e40yXe8BWG
# Did you know two Soviet steppe tortoises had already flown around the moon by the time Neil Armstrong set foot on i… https://t.co/yYJqM7e9jF
# In this striking image, a woman sorts through plastic in the Philippines https://t.co/btye9vHmZl
# Each October, a symphony of colors emerges. Those hues inspired the photographs selected this month https://t.co/QFhB3AmnLj
# Fewer than a hundred artisans still create authentic benjarong porcelain, known for its layers of intricate patterns https://t.co/SX3kXHGrEO
# Shingleback lizards pair for life, a behavior that’s made them popular among reptile collectors—and the poachers wh… https://t.co/oLox8PmNsx
# Almost a third of freshwater fish species are now threatened with extinction—yet it’s a crisis that has received fa… https://t.co/rbdBkvZFFo
# The tools and fashions of 18th-century wigmaking live on at the living history museum at Colonial Williamsburg, Vir… https://t.co/FGEgS7IXiP
# Bees have special hairs that are supposed to attract pollen. A new study shows they’re also accumulating airborne m… https://t.co/HlYa2BmIPS
# “The most common mistake people make when training cats is to ask for too much too soon” https://t.co/wh6kqCvEyb
# Scholars have long suspected the Hope Diamond and the lost French Blue were one and the same. It wasn’t until 2005—… https://t.co/3JkR8AjIN3
# "He was never satisfied, never settled. He was always pushing the boundaries, working outside his comfort zone." Th… https://t.co/T1e9yjVLCI
# Glasgow—whose Gaelic name, Glaschu, fittingly means “dear green place”—is abuzz with new openings as it hosts Novem… https://t.co/AEGRBvZQLy
# Dog lovers proud of their country's unique breed want to make their lives better—and prevent the spread of rabies https://t.co/yRwk3jF7Fp
# Unlike vaccines that can prevent infection, antivirals act as a second line of defense, slowing down and eventually… https://t.co/ZX6sXzc3aW
# Bison graze on the short grasses of a Wyoming prairie in this image from the archives #NationalBisonDay… https://t.co/MbJz0W1RTR
# Each October, a symphony of colors emerges. Those hues inspired the photographs selected this month https://t.co/KLsCU44dBG
# Skepticism is warranted. But billions of dollars have been promised—and new data on carbon emissions provide ground… https://t.co/y4RgFHZIFq
# Shingleback lizards pair for life, a behavior that’s made them popular among reptile collectors—and the poachers wh… https://t.co/kDNvH7gNFr
# It's not the first social media trend to tempt kids into destructive behavior, but its widespread influence left ed… https://t.co/17WCXCGTSB
# Even as the biggest importer in the world of wild animals for pets, the U.S. is failing to set the bar for standard… https://t.co/C4ZQOVFBd0
# A medical mystery to this day, this ancient epidemic decided the final victor of the Peloponnesian War https://t.co/otOFapip8F
# No need to go chasin' waterfalls, these spectacular photos will transport you to some of the world's best https://t.co/wHHbatnGAo
# Observed across many faiths, #Diwali has become India's biggest holiday, rivaling Thanksgiving and Christmas in the… https://t.co/49qHAFzp1C
# Unlike vaccines that can prevent infection, antivirals act as a second line of defense, slowing down and eventually… https://t.co/bbedyUdCKq
# Though officially protected, Javan slow lorises are heavily trafficked in the exotic pet trade (from 2018) https://t.co/n7Ucom9K3m
# Teeth and skull fragments found deep in South Africa's Rising Star cave system fuel debate on how Homo naledi lived… https://t.co/5L7u0IXQnx
# Take a look at the vast cultures and geographies that inspired Marvel Studios’ “Eternals” https://t.co/k8p7NBvpL5
# Fewer than a hundred artisans still create authentic benjarong porcelain, known for its layers of intricate patterns https://t.co/WH3R6V8zjF
# Several companies are working on blood tests, sometimes called liquid biopsies, that can pick up cancer signals in… https://t.co/Je05MhJRi8
# A hiker stands above the entrance to an ice cave in Kluane National Park Reserve, Yukon Territory, Canada https://t.co/cus8h2BKde
# Skepticism is warranted. But billions of dollars have been promised—and new data on carbon emissions provide ground… https://t.co/DAVXc3Zo1A
# Did you know two Soviet steppe tortoises had already flown around the moon by the time Neil Armstrong set foot on i… https://t.co/QEdqFBjttg
# “Consumers will come to expect technologies that make them more confident about travel. Some of these changes are h… https://t.co/VmgGYJO9Zq
# It's not the first social media trend to tempt kids into destructive behavior, but its widespread influence left ed… https://t.co/THiKGcNvBm
# “For me, every animal has the right to be rescued," says Elena Tova, founder and director of the first sanctuary fo… https://t.co/bgINsDYeDe
# Humans scream from a wide range of emotions, from anguish to elation. Studying the diversity of our non-verbal voca… https://t.co/cjfcWMLzKj
# Paul Salopek's 8-year journey on foot has yielded lessons in navigating a troubled world https://t.co/Cww2hWN5WG
# Males need not apply—these California condor ladies are doing just fine on their own https://t.co/q44EJQMGwP
# Nat Geo Explorer Albert Lin is exploring the ancient architecture of the Nabateans, and recreates one of their lost… https://t.co/4uoQqjceTk
# Teeth and skull fragments found deep in South Africa's Rising Star cave system fuel debate on how Homo naledi lived… https://t.co/ButGsxZDZP
# Why is it important to know the blue whale eats up to 16 tons of plankton daily? Because healthy oceans need whales… https://t.co/sdiKXCdiHY
# A hiker crosses a rushing creek in Katmai National Park and Preserve, Alaska, in this image from the archives https://t.co/aIavKBC6IV

# %% [markdown]
# #### Process the text from your tweets search, and from your home

# %%
#combine all text to one big text
hometext = " ".join(twtext for twtext in homedf.Tweet_Text)
searchtext = " ".join(twtext for twtext in twdf.Tweet_Text)

# %% [markdown]
# Remove the stopwords in english from the text of the tweets

# %%
#set stopwords - words to be excluded
stopwords = set(STOPWORDS)
stopwords.update(["RT","t","co","https","amp"]) # include extra strings in this list

#generate word cloud image
wordcloud = WordCloud(stopwords=stopwords).generate(hometext)

#display image with pyplot
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# In case there non-english letters, you can filter them.
# Wordcloud can't display them, so I will use the text file I generated earlier with only tweets twitter detected to be in english language.

# %%
#same with only tweets detected to be in english
wordcloud2 = WordCloud(stopwords=stopwords).generate(home_text_en)

plt.imshow(wordcloud2, interpolation="bilinear")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Lets also try generating a wordcloud for all tweets of a single user. In our example, we used National Geographic, so we can make a wordcloud of the most common words from their 100 tweets retrieved.

# %%
wordcloud_user = WordCloud(stopwords=stopwords).generate(user_text_all)

plt.imshow(wordcloud_user, interpolation="bilinear")
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Now lets fit the wordcloud to a mask

# %%
mask = np.array(Image.open("satellite.jpg"))
wordcloud_img = WordCloud(stopwords=stopwords, background_color="white", mode="RGBA", 
                         max_words=1000, mask=mask).generate(home_text_en)

#create coloring from image
image_colors = ImageColorGenerator(mask)
plt.figure(figsize=[7,7])
plt.imshow(wordcloud_img.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")

#store to file
plt.savefig("satellite_wordcloud.png", format="png")

plt.show()

# %%
#the same with the twitter logo
mask = np.array(Image.open("twitter_logo.png"))
wordcloud_img = WordCloud(stopwords=stopwords, background_color="white", mode="RGBA", 
                         max_words=1000, mask=mask).generate(home_text_en)

#create coloring from image
image_colors = ImageColorGenerator(mask)
plt.figure(figsize=[7,7])
plt.imshow(wordcloud_img.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")

#store to file
plt.savefig("twitter_wordcloud.png", format="png")

plt.show()

# %% [markdown]
# As you can see Wordcloud has some issues fitting to more complex shapes

# %% [markdown]
# ####  Calculate histogram of words

# %%
# lastly a histogram of the 10 most frequent words
from collections import Counter
freq = WordCloud(stopwords=stopwords).process_text(home_text_en)
k = Counter(freq)
highest = k.most_common(10) #this is a tuple object, not a dictionary

x_val = [x[0] for x in highest]
y_val = [x[1] for x in highest]

plt.figure(figsize=[20,20])
plt.bar(x_val,y_val)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# There is a high frequency for the "s" letter. Probably, this has to do with the possesive form in the English language. Try to exclude this letter from the analysis by including it in the stopwords list.
